# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv')

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


df.head()
# Out:
#       CAMIS                      DBA       BORO BUILDING        STREET  ZIPCODE       PHONE                                CUISINE DESCRIPTION INSPECTION DATE                                             ACTION VIOLATION CODE                              VIOLATION DESCRIPTION CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE                                INSPECTION TYPE   Latitude  Longitude  Community Board  Council District  Census Tract        BIN           BBL   NTA
# 0  41488065        BOCA CHICA QUEENS     Queens     9620     37 AVENUE  11368.0  3472422226  Latin (Cuban, Dominican, Puerto Rican, South &...      04/01/2016    Violations were cited in the following area(s).            10F  Non-food contact surface improperly constructe...             N   23.0   NaN         NaN  09/16/2019          Cycle Inspection / Initial Inspection  40.751603 -73.870575            403.0              21.0       37500.0  4043837.0  4.017590e+09  QN26
# ...

# %%
# Rename columns

df = df.rename(columns={'CAMIS': 'RECORD_ID', 'DBA': 'BUSINESS_NAME', 'BORO': 'BOROUGH', 'CUISINE DESCRIPTION': 'CUISINE_DESCRIPTION', 'INSPECTION DATE': 'INSPECTION_DATE', 'VIOLATION CODE': 'VIOLATION_CODE',  'VIOLATION DESCRIPTION': 'VIOLATION_DESCRIPTION',
                  'CRITICAL FLAG': 'CRITICAL_FLAG','GRADE DATE': 'GRADE_DATE', 'RECORD DATE': 'RECORD_DATE', 'INSPECTION TYPE': 'INSPECTION_TYPE', 'Community Board': 'COMMUNITY_BOARD', 'Council District': 'COUNCIL_DISTRICT', 'Census Tract': 'CENCUS_TRUCT'})
df.head()
# Out:
#    RECORD_ID            BUSINESS_NAME    BOROUGH BUILDING        STREET  ZIPCODE       PHONE                                CUISINE_DESCRIPTION INSPECTION_DATE                                             ACTION VIOLATION_CODE                              VIOLATION_DESCRIPTION CRITICAL_FLAG  SCORE GRADE  GRADE_DATE RECORD_DATE                                INSPECTION_TYPE   Latitude  Longitude  COMMUNITY_BOARD  COUNCIL_DISTRICT  CENCUS_TRUCT        BIN           BBL   NTA
# 0   41488065        BOCA CHICA QUEENS     Queens     9620     37 AVENUE  11368.0  3472422226  Latin (Cuban, Dominican, Puerto Rican, South &...      04/01/2016    Violations were cited in the following area(s).            10F  Non-food contact surface improperly constructe...             N   23.0   NaN         NaN  09/16/2019          Cycle Inspection / Initial Inspection  40.751603 -73.870575            403.0              21.0       37500.0  4043837.0  4.017590e+09  QN26
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# RECORD_ID                     0
# BUSINESS_NAME               551
# BOROUGH                       0
# BUILDING                    252
# STREET                       16
# ZIPCODE                    5540
# PHONE                        11
# CUISINE_DESCRIPTION           0
# INSPECTION_DATE               0
# ACTION                     1271
# VIOLATION_CODE             5634
# VIOLATION_DESCRIPTION      8847
# CRITICAL_FLAG              8847
# SCORE                     17022
# GRADE                    192496
# GRADE_DATE               194514
# RECORD_DATE                   0
# INSPECTION_TYPE            1271
# Latitude                    415
# Longitude                   415
# COMMUNITY_BOARD            5939
# COUNCIL_DISTRICT           5939
# CENCUS_TRUCT               5939
# BIN                        7579
# BBL                         415
# NTA                        5939
# dtype: int64

# %%
#filling Na with zeros

df = df.fillna(0)
df.head()
# Out:
#    RECORD_ID            BUSINESS_NAME    BOROUGH BUILDING        STREET  ZIPCODE       PHONE                                CUISINE_DESCRIPTION INSPECTION_DATE                                             ACTION VIOLATION_CODE                              VIOLATION_DESCRIPTION CRITICAL_FLAG  SCORE GRADE  GRADE_DATE RECORD_DATE                                INSPECTION_TYPE   Latitude  Longitude  COMMUNITY_BOARD  COUNCIL_DISTRICT  CENCUS_TRUCT        BIN           BBL   NTA
# 0   41488065        BOCA CHICA QUEENS     Queens     9620     37 AVENUE  11368.0  3472422226  Latin (Cuban, Dominican, Puerto Rican, South &...      04/01/2016    Violations were cited in the following area(s).            10F  Non-food contact surface improperly constructe...             N   23.0     0           0  09/16/2019          Cycle Inspection / Initial Inspection  40.751603 -73.870575            403.0              21.0       37500.0  4043837.0  4.017590e+09  QN26
# ...

# %%
#Cleaned data
df.isnull().sum()
# Out:
# RECORD_ID                0
# BUSINESS_NAME            0
# BOROUGH                  0
# BUILDING                 0
# STREET                   0
# ZIPCODE                  0
# PHONE                    0
# CUISINE_DESCRIPTION      0
# INSPECTION_DATE          0
# ACTION                   0
# VIOLATION_CODE           0
# VIOLATION_DESCRIPTION    0
# CRITICAL_FLAG            0
# SCORE                    0
# GRADE                    0
# GRADE_DATE               0
# RECORD_DATE              0
# INSPECTION_TYPE          0
# Latitude                 0
# Longitude                0
# COMMUNITY_BOARD          0
# COUNCIL_DISTRICT         0
# CENCUS_TRUCT             0
# BIN                      0
# BBL                      0
# NTA                      0
# dtype: int64

# %%
df
# Out:
#    RECORD_ID            BUSINESS_NAME    BOROUGH BUILDING        STREET  ZIPCODE       PHONE                                CUISINE_DESCRIPTION INSPECTION_DATE                                             ACTION VIOLATION_CODE                              VIOLATION_DESCRIPTION CRITICAL_FLAG  SCORE GRADE  GRADE_DATE RECORD_DATE                                INSPECTION_TYPE   Latitude  Longitude  COMMUNITY_BOARD  COUNCIL_DISTRICT  CENCUS_TRUCT        BIN           BBL   NTA
# 0   41488065        BOCA CHICA QUEENS     Queens     9620     37 AVENUE  11368.0  3472422226  Latin (Cuban, Dominican, Puerto Rican, South &...      04/01/2016    Violations were cited in the following area(s).            10F  Non-food contact surface improperly constructe...             N   23.0     0           0  09/16/2019          Cycle Inspection / Initial Inspection  40.751603 -73.870575            403.0              21.0       37500.0  4043837.0  4.017590e+09  QN26
# ...
